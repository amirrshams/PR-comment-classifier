# %%
import requests
import pandas as pd
pd.set_option('max_colwidth', 100)
from tqdm.auto import tqdm
from time import sleep
import vaex

# %%
# existing_data = pd.read_csv("/Users/amirrshams/UW/Thesis/Github/GHtorrent/pr_1.csv")
df = pd.read_csv('/Users/amirrshams/UW/Thesis/Datasets/non_merged/pr_non_merged_v2.csv')

# %%
tokenList=["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","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","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","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","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","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","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","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","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","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","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"]
token_index = 0
headers= {"Authorization": "token " + tokenList[token_index]}

# %%
df.head()
# Out:
# Unnamed: 0             435248
# repo_id                435248
# status                 435248
# pr_id                  435248
# pullreq_id             435248
# api_url                435248
#  url                   435248
# pr_url                 435248
# pr_api_url             435248
# author_id              435248
# author_desc_body       359367
# closer_id                   0
# comments_counts        435248
# comments               435248
# commit_counts          435248
# code_changes_counts    435248
# created_at             435248
# closed_at              435233
# checked                435248
# author_country         435248
# closer_country         435248
# author_continent       435248
# same_country           435248
# author_eth             435248
# closer_eth             435248
# same_eth               435248
# dtype: int64

# %%
df[df['comments_counts'] == "Deleted"].count()
# Out:
# Unnamed: 0             0
# repo_id                0
# status                 0
# pr_id                  0
# pullreq_id             0
# api_url                0
#  url                   0
# pr_url                 0
# pr_api_url             0
# author_id              0
# author_desc_body       0
# closer_id              0
# comments_counts        0
# comments               0
# commit_counts          0
# code_changes_counts    0
# created_at             0
# closed_at              0
# checked                0
# dtype: int64

# %%
df.count()
# Out:
# Unnamed: 0             1981546
# repo_id                1981546
# status                 1981546
# pr_id                  1981546
# pullreq_id             1981546
# api_url                1981546
#  url                   1981546
# pr_url                 1981546
# pr_api_url             1981546
# author_id              1981546
# author_desc_body       1546254
# closer_id              1973918
# comments_counts        1981546
# comments               1973995
# commit_counts          1981546
# code_changes_counts    1981546
# created_at             1981546
# closed_at              1981515
# checked                1981546
# dtype: int64

# %%
df[df['Unnamed: 0'].isnull()].head(10)
# Out:
#          Unnamed: 0   repo_id status  \
# 586927          NaN      lzap    1.0
# 1487817         NaN  turtleli   27.0
#
#                                                                                                        pr_id  \
# 586927                                    ['Issues: [#24662](https://projects.theforeman.org/issues/24662)']
# 1487817  ['Any reason as to why clang-format is failing in Travis? I had a feeling some tabs/spaces got m...
#
#          pullreq_id api_url                   url                pr_url  \
# 586927          1.0     2.0  2018-10-02T11:13:31Z  2018-10-10T13:31:37Z
# 1487817         3.0    17.0  2017-06-05T23:01:04Z  2018-02-05T22:49:10Z
#
#         pr_api_url author_id author_desc_body closer_id  comments_counts  \
# 586927         0.0       NaN              NaN       NaN              NaN
# 1487817        0.0       NaN              NaN       NaN              NaN
#
#         comments  commit_counts  code_changes_counts created_at closed_at  \
# ...

# %%
df_merged = df.drop(df[df['Unnamed: 0'].isnull()].index)

# %%
df_merged.count()
# Out:
# Unnamed: 0             1981548
# repo_id                1981548
# status                 1981548
# pr_id                  1981548
# pullreq_id             1981548
# api_url                1981548
#  url                   1981548
# pr_url                 1981548
# pr_api_url             1981548
# author_id              1981548
# author_desc_body       1546256
# closer_id              1973920
# comments_counts        1981548
# comments               1973997
# commit_counts          1981548
# code_changes_counts    1981548
# created_at             1981548
# closed_at              1981517
# checked                1981548
# dtype: int64

# %%
#save the dataframe to a csv file with vaex
df_merged.vaex.export_csv('/Users/amirrshams/UW/Thesis/Datasets/merged/Output/pr_merged_final.csv', write_index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/v7/m50ww3p142130jtt2scggl3r0000gq/T/ipykernel_29716/668036147.py in <module>
#       1 #save the dataframe to a csv file with vaex
# ----> 2 df_merged.vaex.export_csv('/Users/amirrshams/UW/Thesis/Datasets/merged/Output/pr_merged_final.csv', write_index=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'vaex'

# %%
df_merged.to_csv('/Users/amirrshams/UW/Thesis/Datasets/merged/Output/pr_merged_final.csv', index=False)

# %%
# df.at[index, "author_id"] = None
# df.at[index, "author_desc_body"] = None
# df.at[index, "closer_id"] = None
# df.at[index, "comments_counts"] = None
# df.at[index, "comments"] = None
# df.at[index, "commit_counts"] = None
# df.at[index, "code_changes_counts"] = None
# df.at[index, "created_at"] = None
# df.at[index, "closed_at"] = None
# df.at[index, "checked"] = None

# if "checked" not in df.columns:
#     # If it doesn't exist, assume none of the rows have been checked yet
#     df["checked"] = None    
#df['comments'] = df['comments'].astype('object')
# first_unchecked_index = df[df['checked'].isnull()].index[0]
df['pr_api_url'].fillna(df['pr_url'], inplace=True)
index = 0
for index, url in tqdm(enumerate(df.pr_api_url)):
#     if pd.isnull(url) or df.at[index, 'checked'] == "1" or index < first_unchecked_index:
#         continue
#     if index < 49500:
#         continue
    # if index < first_unchecked_index:
        # continue?

#     if pd.isnull(url):
#         df.at[index, 'checked'] = 0
#         continue

#     if df.at[index, 'checked'] == "1":
#         continue
#    if pd.isnull(url):
#        df.at[index, "pr_api_url"] = df.pr_url
    #if pd.isna(df.at[index, 'closer_id']):
     #   continue

     
    # if df.at[index, 'comments_counts'] != "Deleted":
        # continue
    if pd.notnull(df.at[index, 'comments_counts']):
        continue


    # if df.at[index, 'comments_counts'].notnull():
    #     continue
#     if (df['comments_counts'] != "Deleted").any():
#         continue
#     if df['comments_counts'].notnull().any():
#         continue
    try:
        response = requests.get(url, headers=headers)
        rate_limit_remaining = int(response.headers["X-RateLimit-Remaining"])
    except Exception as e:
        print(f"An error occurred while sending a request to {url}: {e}")
        pass
    while rate_limit_remaining < 50:
        token_index = (token_index + 1)
        if token_index >= len(tokenList):
            token_index = 0        
        headers = {"Authorization": "token " + tokenList[token_index]}   
        try:
            response = requests.get(url, headers=headers)
            rate_limit_remaining = int(response.headers["X-RateLimit-Remaining"])
        except KeyError:
            print("The 'X-RateLimit-Remaining' header is not present in the response.")
            pass
        sleep(10)

    
    if response.status_code == 200:
        pull_request = response.json()
        


        author_id = pull_request["user"]["login"]
        closer_id = pull_request["merged_by"]["login"] if pull_request["merged_by"] else None
        author_pr_comment = pull_request["body"]
        # Get the comments
        comments_url = pull_request["comments_url"]
        try:
            comments_response = requests.get(comments_url, headers=headers)
            if comments_response.status_code == 200:
                comments_data = comments_response.json()
                comments_body = [comment["body"] for comment in comments_data]
            else:
                print("Failed to retrieve comments for pull request:", comments_response.json()["message"])
                comments_body = None
        except Exception as e:
            print(f"An error occurred while sending a request to {url}: {e}")
            continue        
        commits_count = pull_request["commits"]
        code_changes = pull_request["changed_files"]
        creation_date = pull_request["created_at"]
        closing_date = pull_request["closed_at"]
        comments_counts = pull_request["comments"]
        completed = 0 if pd.isna(df.at[index, "checked"]) else "1"
        
        # Add the new data to the existing data
        df.at[index, "author_id"] = author_id
        df.at[index, "author_desc_body"] = author_pr_comment
        df.at[index, "closer_id"] = closer_id
        df.at[index, "comments_counts"] = comments_counts
        df.at[index, "comments"] = comments_body
        df.at[index, "commit_counts"] = commits_count
        df.at[index, "code_changes_counts"] = code_changes
        df.at[index, "created_at"] = creation_date
        df.at[index, "closed_at"] = closing_date
        df.at[index, "checked"] = completed
        
#         if index % 500 == 0:
#             df.to_csv("pull_request_test1.csv", index=False)
#             df.to_csv("/Users/amirrshams/UW/Thesis/Datasets/non_merged/output_batches/Final/pr_output_non_merged_deleted_checked.csv", index=False)
        #df.to_csv("pr_test.csv", index=False)
        
    else:
        # Add the error message to the existing data
#         existing_data.at[index, "error"] = "Failed to retrieve pull request data: " + response.json()["message"]
        df.at[index, "checked"] = "1"
        df.at[index, "author_id"] = "Deleted"
        df.at[index, "author_desc_body"] = "Deleted"
        df.at[index, "closer_id"] = "Deleted"
        df.at[index, "comments_counts"] = "Deleted"
        df.at[index, "comments"] = "Deleted"
        df.at[index, "commit_counts"] = "Deleted"
        df.at[index, "code_changes_counts"] = "Deleted"
        df.at[index, "created_at"] = "Deleted"
        df.at[index, "closed_at"] = "Deleted"
# Out:
# 0it [00:00, ?it/s]
# An error occurred while sending a request to 0: Invalid URL '0': No scheme supplied. Perhaps you meant http://0?
# An error occurred while sending a request to 0: Invalid URL '0': No scheme supplied. Perhaps you meant http://0?
# An error occurred while sending a request to 0: Invalid URL '0': No scheme supplied. Perhaps you meant http://0?
# An error occurred while sending a request to 0: Invalid URL '0': No scheme supplied. Perhaps you meant http://0?
# An error occurred while sending a request to 0: Invalid URL '0': No scheme supplied. Perhaps you meant http://0?
# An error occurred while sending a request to 0: Invalid URL '0': No scheme supplied. Perhaps you meant http://0?

# %%
df.to_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/Output/pr_output_batch_1.csv", index=False)

# %%
df = df[df.pr_api_url.isna()]

# %%
deleted_df = df[df['closer_id'].notnull()]

# %%
deleted_df.head(250)
# Out:
#       Unnamed: 0  repo_id      status    pr_id  pullreq_id  \
# 2147       13956       34  not-merged  6794610         745
# 2148       13973       63  not-merged   841938          70
# 2149       13980       63  not-merged  1180449         108
# 2150       13987       63  not-merged  1443940         162
# 2151       13988       63  not-merged  1586591         199
# ...          ...      ...         ...      ...         ...
# 7718       30268      354  not-merged   208825        1824
# 7719       30269      354  not-merged   213307        1827
# 7720       30270      354  not-merged   213325        1828
# 7721       30271      354  not-merged   213526        1829
# 7722       30272      354  not-merged   217465        1830
#
#                                                api_url  \
# 2147  https://api.github.com/repos/pockethub/PocketHub
# 2148     https://api.github.com/repos/pculture/unisubs
# 2149     https://api.github.com/repos/pculture/unisubs
# ...

# %%
df_nonmerged = df.drop(df[df['closer_id'] == 'Deleted'].index)

# %%
df_nonmerged.count()
# Out:
# Unnamed: 0             435320
# repo_id                435320
# status                 435320
# pr_id                  435320
# pullreq_id             435320
# api_url                435320
#  url                   435320
# pr_url                 435320
# pr_api_url             435320
# author_id              435320
# author_desc_body       359220
# closer_id                1402
# comments_counts        435320
# comments               435320
# commit_counts          435320
# code_changes_counts    435320
# created_at             435320
# closed_at              435305
# checked                435320
# dtype: int64

# %%
deleted_df = df_nonmerged_final[df_nonmerged_final['closer_id'].notnull()]

# %%
deleted_df.to_csv("/Users/amirrshams/UW/Thesis/Datasets/non_merged/output_batches/Final/pr_changed_status.csv", index=False)

# %%
deleted_df.head()
# Out:
#        Unnamed: 0  repo_id      status    pr_id  pullreq_id  \
# 39263      204546     2309  not-merged  2765967          69
# 39265      204548     2309  not-merged  3160105          85
# 39266      204549     2309  not-merged  3200316          88
# 44866      231366     3371  not-merged  2212774          40
# 44867      231368     3371  not-merged  2793895          46
#
#                                                        api_url  \
# 39263  https://api.github.com/repos/BroadleafCommerce/DemoSite
# 39265  https://api.github.com/repos/BroadleafCommerce/DemoSite
# 39266  https://api.github.com/repos/BroadleafCommerce/DemoSite
# 44866                https://api.github.com/repos/twisted/treq
# 44867                https://api.github.com/repos/twisted/treq
#
#                                                  url  \
# 39263  https://github.com/BroadleafCommerce/DemoSite
# 39265  https://github.com/BroadleafCommerce/DemoSite
# 39266  https://github.com/BroadleafCommerce/DemoSite
# ...

# %%
df_changed_status = pd.read_csv("/Users/amirrshams/UW/Thesis/Datasets/non_merged/output_batches/Final/pr_changed_status.csv")

# %%
df_changed_status.count()
# Out:
# Unnamed: 0             1402
# repo_id                1402
# status                 1402
# pr_id                  1402
# pullreq_id             1402
# api_url                1402
#  url                   1402
# pr_url                 1402
# pr_api_url             1402
# author_id              1402
# author_desc_body        927
# closer_id              1402
# comments_counts        1402
# comments               1402
# commit_counts          1402
# code_changes_counts    1402
# created_at             1402
# closed_at              1402
# checked                1402
# dtype: int64

# %%
df_nonmerged_final.to_csv("/Users/amirrshams/UW/Thesis/Datasets/non_merged/output_batches/Final/pr_non_merged.csv", index=False)
