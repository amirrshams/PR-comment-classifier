# %%
import pandas as pd
pd.set_option('max_colwidth', 100)
pd.options.display.max_columns = None

# %%
df_as = pd.read_csv("/Users/amirrshams/UW/Thesis/Datasets/non_merged/output_batches/Final/pr_non_merged.csv")
df_ieee = pd.read_csv("/Users/amirrshams/UW/Thesis/Reza's Dataset/TSE paper/2020-TSE-Developers-Perceptible-Ethnicity-and-PR-evaluation-main/Dataset/pull_requests_TSE.csv")
# Out:
# /var/folders/v7/m50ww3p142130jtt2scggl3r0000gq/T/ipykernel_51795/1904972814.py:2: DtypeWarning: Columns (8,14,31,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ieee = pd.read_csv("/Users/amirrshams/UW/Thesis/Reza's Dataset/TSE paper/2020-TSE-Developers-Perceptible-Ethnicity-and-PR-evaluation-main/Dataset/pull_requests_TSE.csv")

# %%
df_as_merged = pd.read_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/pr_merged_final.csv")

# %%
df_as.head()
# Out:
#    Unnamed: 0  repo_id      status    pr_id  pullreq_id  \
# 0           0        2  not-merged    33026          18
# 1          12        3  not-merged   668439           6
# 2          13        3  not-merged   668442           2
# 3          32        3  not-merged  3602435         152
# 4          33        3  not-merged  6398432         181
#
#                                                 api_url  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit
# 1       https://api.github.com/repos/matplotlib/basemap
# 2       https://api.github.com/repos/matplotlib/basemap
# 3       https://api.github.com/repos/matplotlib/basemap
# 4       https://api.github.com/repos/matplotlib/basemap
#
#                                           url  \
# 0  https://github.com/kennethkalmer/ruote-kit
# 1       https://github.com/matplotlib/basemap
# 2       https://github.com/matplotlib/basemap
# 3       https://github.com/matplotlib/basemap
# 4       https://github.com/matplotlib/basemap
#
#                                                pr_url  \
# 0  https://github.com/kennethkalmer/ruote-kit/pull/18
# 1        https://github.com/matplotlib/basemap/pull/6
# 2        https://github.com/matplotlib/basemap/pull/2
# 3      https://github.com/matplotlib/basemap/pull/152
# 4      https://github.com/matplotlib/basemap/pull/181
#
#                                                       pr_api_url  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/18
# 1        https://api.github.com/repos/matplotlib/basemap/pulls/6
# 2        https://api.github.com/repos/matplotlib/basemap/pulls/2
# 3      https://api.github.com/repos/matplotlib/basemap/pulls/152
# 4      https://api.github.com/repos/matplotlib/basemap/pulls/181
#
#       author_id  \
# 0       reedlaw
# 1  mollyswanson
# 2        mdboom
# 3   aaschwanden
# 4       sbellem
#
#                                                                                       author_desc_body  \
# 0                                                                                                  NaN
# 1  I would like to suggest the attached fixes for the basemap module to improve its treatment of ce...
# 2  Matplotlib recently removed its crufty copy of inheritance_diagram, since a better one has exist...
# 3                                                            ...ested by guzly. Resolves issue #151.\n
# 4                                                                                                  NaN
#
#    closer_id  comments_counts  \
# 0        NaN              1.0
# 1        NaN              1.0
# 2        NaN              1.0
# 3        NaN              2.0
# 4        NaN              1.0
#
#                                                                                               comments  \
# 0  ["Hello, thanks for the pull request. I fixed it in another way for https://github.com/kennethka...
# 1                                                                    ['applied to master - thanks!\n']
# 2                                                     ['Fixed this some time ago, closing now ....\n']
# 3  ['Sorry it took me so long to get to this.\n\nLooks reasonable - but could you modify the readsh...
# 4  ['Closing as this is significantly out of date now, and seems like the original author has lost ...
#
#    commit_counts  code_changes_counts            created_at  \
# 0            1.0                  1.0  2012-02-16T22:18:05Z
# 1            2.0                  1.0  2011-11-29T22:29:33Z
# 2            1.0                  1.0  2011-04-07T17:15:06Z
# 3            1.0                  1.0  2014-04-29T17:23:44Z
# 4            3.0                  1.0  2015-02-23T23:46:02Z
#
#               closed_at  checked
# 0  2012-02-18T02:13:05Z      1.0
# 1  2011-11-29T23:22:46Z      1.0
# 2  2011-10-15T16:35:35Z      1.0
# 3  2016-09-23T20:06:30Z      1.0
# 4  2016-09-23T20:05:19Z      1.0

# %%
df_ieee.head()
# Out:
#    Unnamed: 0  repo_id   pr_status  prs_id    pr_id  repo_pr_tenure_mnth  \
# 0           1        2  not-merged   29988    33026                   32
# 1           2        2      merged  282734   852598                   30
# 2           3        2      merged  282734  1052366                   30
# 3           4        3      merged  163945    12308                   17
# 4           5        3      merged  163945   148263                   18
#
#    repo_pr_popularity  repo_pr_team_size perc_external_contribs  pr_opened_at  \
# 0                   1                  0                    100    1329427085
# 1                   1                  2                    100    1325669029
# 2                   1                  3                    100    1323724213
# 3                  37                  0                     35    1344393044
# 4                  38                  6                     38    1345400474
#
#      prs_country  prs_continent prm_country prc_country  \
# 0  united states  North America          \N       japan
# 1             \N             \N       japan       japan
# 2             \N             \N       japan       japan
# 3  united states  North America          \N          \N
# 4  united states  North America          \N          \N
#
#   prs_pri_same_nationality  prs_experience  prs_succ_rate  pr_files_changed  \
# 0                        0               7             29                 0
# 1                        0               6             33                 0
# 2                        0               5             20                 0
# 3                        0               0              0                 0
# 4                        0               2            100                 0
#
#    pr_lines_changed  prs_main_team_member  prs_popularity  prs_watched_repo  \
# 0                 0                     0               9                 0
# 1                 0                     0               2                 0
# 2                 0                     0               2                 0
# 3                 0                     0              21                 0
# 4                 0                     0              21                 0
#
#    prs_followed_pri  prs_tenure_mnth  pr_comments_counts  pr_num_commits  \
# 0                 0               47                   8               1
# 1                 0               10                  17               1
# 2                 0                9                   4               1
# 3                 1               28                   4               4
# 4                 1               28                   1               2
#
#    prs_eth prc_eth  prm_eth  pr_nth  same_eth pri_id  intra_branch prm_id  \
# 0    White   White  Unknown       1         1      2             0     \N
# 1  Unknown   White    White       2         0      2             0      2
# 2  Unknown   White    White       1         0      2             0      2
# 3    White   White    White       1         1     24             0     24
# 4    White   White    White       3         1     24             0     24
#
#   prc_id pri_id.1  prs_white   prs_api  prs_black  prs_hispanic  pri_white  \
# 0      2        2   0.923822  0.030206   0.043507      0.001134   0.974386
# 1      2        2   0.763503  0.187838   0.007003      0.001286   0.974386
# 2      2        2   0.763503  0.187838   0.007003      0.001286   0.974386
# 3     24       24   0.964081  0.001878   0.030626      0.001998   0.937730
# 4     24       24   0.964081  0.001878   0.030626      0.001998   0.937730
#
#    pri_black   pri_api  pri_hispanic prs_eth_8 prs_eth_7 prs_eth_9  \
# 0   0.011098  0.005310      0.008516     White     White     White
# 1   0.011098  0.005310      0.008516   Unknown     White   Unknown
# 2   0.011098  0.005310      0.008516   Unknown     White   Unknown
# 3   0.058950  0.000949      0.001142     White     White     White
# 4   0.058950  0.000949      0.001142     White     White     White
#
#   prs_eth_diff prs_eth_diff_2
# 0        White          White
# 1      Unknown        Unknown
# 2      Unknown        Unknown
# 3        White          White
# 4        White          White

# %%
df_merged.head()
# Out:
#    Unnamed: 0  repo_id      status    pr_id  pullreq_id  \
# 0           0        2  not-merged    33026          18
# 1          12        3  not-merged   668439           6
# 2          13        3  not-merged   668442           2
# 3          32        3  not-merged  3602435         152
# 4          33        3  not-merged  6398432         181
#
#                                                 api_url  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit
# 1       https://api.github.com/repos/matplotlib/basemap
# 2       https://api.github.com/repos/matplotlib/basemap
# 3       https://api.github.com/repos/matplotlib/basemap
# 4       https://api.github.com/repos/matplotlib/basemap
#
#                                           url  \
# 0  https://github.com/kennethkalmer/ruote-kit
# 1       https://github.com/matplotlib/basemap
# 2       https://github.com/matplotlib/basemap
# 3       https://github.com/matplotlib/basemap
# 4       https://github.com/matplotlib/basemap
#
#                                                pr_url  \
# 0  https://github.com/kennethkalmer/ruote-kit/pull/18
# 1        https://github.com/matplotlib/basemap/pull/6
# 2        https://github.com/matplotlib/basemap/pull/2
# 3      https://github.com/matplotlib/basemap/pull/152
# 4      https://github.com/matplotlib/basemap/pull/181
#
#                                                       pr_api_url  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/18
# 1        https://api.github.com/repos/matplotlib/basemap/pulls/6
# 2        https://api.github.com/repos/matplotlib/basemap/pulls/2
# 3      https://api.github.com/repos/matplotlib/basemap/pulls/152
# 4      https://api.github.com/repos/matplotlib/basemap/pulls/181
#
#       author_id  \
# 0       reedlaw
# 1  mollyswanson
# 2        mdboom
# 3   aaschwanden
# 4       sbellem
#
#                                                                                       author_desc_body  \
# 0                                                                                                  NaN
# 1  I would like to suggest the attached fixes for the basemap module to improve its treatment of ce...
# 2  Matplotlib recently removed its crufty copy of inheritance_diagram, since a better one has exist...
# 3                                                            ...ested by guzly. Resolves issue #151.\n
# 4                                                                                                  NaN
#
#    closer_id  comments_counts  \
# 0        NaN              1.0
# 1        NaN              1.0
# 2        NaN              1.0
# 3        NaN              2.0
# 4        NaN              1.0
#
#                                                                                               comments  \
# 0  ["Hello, thanks for the pull request. I fixed it in another way for https://github.com/kennethka...
# 1                                                                    ['applied to master - thanks!\n']
# 2                                                     ['Fixed this some time ago, closing now ....\n']
# 3  ['Sorry it took me so long to get to this.\n\nLooks reasonable - but could you modify the readsh...
# 4  ['Closing as this is significantly out of date now, and seems like the original author has lost ...
#
#    commit_counts  code_changes_counts            created_at  \
# 0            1.0                  1.0  2012-02-16T22:18:05Z
# 1            2.0                  1.0  2011-11-29T22:29:33Z
# 2            1.0                  1.0  2011-04-07T17:15:06Z
# 3            1.0                  1.0  2014-04-29T17:23:44Z
# 4            3.0                  1.0  2015-02-23T23:46:02Z
#
#               closed_at  checked    prs_country prc_country  prs_continent  \
# 0  2012-02-18T02:13:05Z      1.0  united states       japan  North America
# 1  2011-11-29T23:22:46Z      1.0             \N          \N             \N
# 2  2011-10-15T16:35:35Z      1.0  united states          \N  North America
# 3  2016-09-23T20:06:30Z      1.0  united states          \N  North America
# 4  2016-09-23T20:05:19Z      1.0             \N          \N             \N
#
#   prs_pri_same_nationality prs_eth prc_eth  same_eth
# 0                        0   White   White         1
# 1                        0   White   White         1
# 2                        0   White   White         1
# 3                        0   White   White         1
# 4                        0   White   White         1

# %%
df_as.count()
# Out:
# Unnamed: 0             433391
# repo_id                433391
# status                 433391
# pr_id                  433391
# pullreq_id             433391
# api_url                433391
#  url                   433391
# pr_url                 433391
# pr_api_url             433391
# author_id              433391
# author_desc_body       357867
# closer_id                   0
# comments_counts        433391
# comments               433391
# commit_counts          433391
# code_changes_counts    433391
# created_at             433391
# closed_at              433376
# checked                433391
# dtype: int64

# %%
df_ieee.count()
# Out:
# Unnamed: 0                  2507591
# repo_id                     2507591
# pr_status                   2507591
# prs_id                      2507591
# pr_id                       2507591
# repo_pr_tenure_mnth         2507591
# repo_pr_popularity          2507591
# repo_pr_team_size           2507591
# perc_external_contribs      2507591
# pr_opened_at                2507591
# prs_country                 2507591
# prs_continent               2507591
# prm_country                 2507591
# prc_country                 2507591
# prs_pri_same_nationality    2507591
# prs_experience              2507591
# prs_succ_rate               2507591
# pr_files_changed            2507591
# pr_lines_changed            2507591
# prs_main_team_member        2507591
# prs_popularity              2507591
# prs_watched_repo            2507591
# prs_followed_pri            2507591
# prs_tenure_mnth             2507591
# pr_comments_counts          2507591
# pr_num_commits              2507591
# prs_eth                     2507591
# prc_eth                     2507591
# prm_eth                     2507591
# pr_nth                      2507591
# same_eth                    2507591
# pri_id                      2507591
# intra_branch                2507591
# prm_id                      2507591
# prc_id                      2507591
# pri_id.1                    2507591
# prs_white                   2428592
# prs_api                     2428592
# prs_black                   2428592
# prs_hispanic                2428592
# pri_white                   2466276
# pri_black                   2466276
# pri_api                     2466276
# pri_hispanic                2466276
# prs_eth_8                   2507591
# prs_eth_7                   2507591
# prs_eth_9                   2507591
# prs_eth_diff                2507591
# prs_eth_diff_2              2507591
# dtype: int64

# %%
# old merged counts
df_as_merged.count()
# Out:
# Unnamed: 0             1980653
# repo_id                1980653
# status                 1980653
# pr_id                  1980653
# pullreq_id             1980653
# api_url                1980653
#  url                   1980653
# pr_url                 1980653
# pr_api_url             1980653
# author_id              1980653
# author_desc_body       1545542
# closer_id              1973123
# comments_counts        1980653
# comments               1973106
# commit_counts          1980653
# code_changes_counts    1980653
# created_at             1980653
# closed_at              1980622
# checked                1980653
# dtype: int64

# %% [markdown]
# 1330 descripencies

# %%
df_as_merged[df_as_merged.duplicated(['pr_id'])].count()
# Out:
# Unnamed: 0             0
# repo_id                0
# status                 0
# pr_id                  0
# pullreq_id             0
# api_url                0
#  url                   0
# pr_url                 0
# pr_api_url             0
# author_id              0
# author_desc_body       0
# closer_id              0
# comments_counts        0
# comments               0
# commit_counts          0
# code_changes_counts    0
# created_at             0
# closed_at              0
# checked                0
# dtype: int64

# %%
# df_as counts duplicated
df_as[df_as.duplicated(['pr_id'])].count()
# Out:
# Unnamed: 0             0
# repo_id                0
# status                 0
# pr_id                  0
# pullreq_id             0
# api_url                0
#  url                   0
# pr_url                 0
# pr_api_url             0
# author_id              0
# author_desc_body       0
# closer_id              0
# comments_counts        0
# comments               0
# commit_counts          0
# code_changes_counts    0
# created_at             0
# closed_at              0
# checked                0
# dtype: int64

# %%
#drop the rows with this criteria: df_as[df_as.duplicated(['pr_id'])]
df_as_merged = df_as_merged.drop_duplicates(subset=['pr_id'], keep='first')

# %%
df_as.count()
# Out:
# Unnamed: 0             433391
# repo_id                433391
# status                 433391
# pr_id                  433391
# pullreq_id             433391
# api_url                433391
#  url                   433391
# pr_url                 433391
# pr_api_url             433391
# author_id              433391
# author_desc_body       357867
# closer_id                   0
# comments_counts        433391
# comments               433391
# commit_counts          433391
# code_changes_counts    433391
# created_at             433391
# closed_at              433376
# checked                433391
# dtype: int64

# %%
df_ieee[df_ieee.duplicated(['pr_id'])].count()
# Out:
# Unnamed: 0                  0
# repo_id                     0
# pr_status                   0
# prs_id                      0
# pr_id                       0
# repo_pr_tenure_mnth         0
# repo_pr_popularity          0
# repo_pr_team_size           0
# perc_external_contribs      0
# pr_opened_at                0
# prs_country                 0
# prs_continent               0
# prm_country                 0
# prc_country                 0
# prs_pri_same_nationality    0
# prs_experience              0
# prs_succ_rate               0
# pr_files_changed            0
# pr_lines_changed            0
# prs_main_team_member        0
# prs_popularity              0
# prs_watched_repo            0
# prs_followed_pri            0
# prs_tenure_mnth             0
# pr_comments_counts          0
# pr_num_commits              0
# prs_eth                     0
# prc_eth                     0
# prm_eth                     0
# pr_nth                      0
# same_eth                    0
# pri_id                      0
# intra_branch                0
# prm_id                      0
# prc_id                      0
# pri_id.1                    0
# prs_white                   0
# prs_api                     0
# prs_black                   0
# prs_hispanic                0
# pri_white                   0
# pri_black                   0
# pri_api                     0
# pri_hispanic                0
# prs_eth_8                   0
# prs_eth_7                   0
# prs_eth_9                   0
# prs_eth_diff                0
# prs_eth_diff_2              0
# dtype: int64

# %%
df_ieee = df_ieee.drop_duplicates(subset=['pr_id'], keep='first')

# %%
df_merged = pd.merge(df_as_merged, df_ieee[['pr_id', 'prs_country', 'prc_country','prs_continent', 'prs_pri_same_nationality', 'prs_eth', 'prc_eth', 'same_eth', 'prs_white', 'prs_api', 'prs_black', 'prs_hispanic', 'pri_white', 'pri_black', 'pri_api', 'pri_hispanic', 'prs_eth_8', 'prs_eth_7', 'prs_eth_9', 'prs_eth_diff', 'prs_eth_diff_2']], on='pr_id', how='left', validate='one_to_one')

# %%
df_merged.count()
# Out:
# Unnamed: 0                  1980653
# repo_id                     1980653
# status                      1980653
# pr_id                       1980653
# pullreq_id                  1980653
# api_url                     1980653
#  url                        1980653
# pr_url                      1980653
# pr_api_url                  1980653
# author_id                   1980653
# author_desc_body            1545542
# closer_id                   1973123
# comments_counts             1980653
# comments                    1973106
# commit_counts               1980653
# code_changes_counts         1980653
# created_at                  1980653
# closed_at                   1980622
# checked                     1980653
# prs_country                 1980653
# prc_country                 1980653
# prs_continent               1980653
# prs_pri_same_nationality    1980653
# prs_eth                     1980653
# prc_eth                     1980653
# same_eth                    1980653
# prs_white                   1922111
# prs_api                     1922111
# prs_black                   1922111
# prs_hispanic                1922111
# pri_white                   1949162
# pri_black                   1949162
# pri_api                     1949162
# pri_hispanic                1949162
# prs_eth_8                   1980653
# prs_eth_7                   1980653
# prs_eth_9                   1980653
# prs_eth_diff                1980653
# prs_eth_diff_2              1980653
# dtype: int64

# %%
df_complete = df_complete.rename({'prs_country' : 'author_country','prc_country':'closer_country', 'prs_continent': 'author_continent' , 'prs_pri_same_nationality': 'same_country' ,'prs_eth': 'author_eth', 'prc_eth': 'closer_eth'}, axis='columns')

# %%
df_complete = df_complete.drop(['checked'], axis=1)

# %%
df_merged.head()
# Out:
#    Unnamed: 0  repo_id  status    pr_id  pullreq_id  \
# 0         1.0        2  merged   852598          16
# 1         2.0        2  merged  1052366          14
# 2         3.0        3  merged    12308          64
# 3         4.0        3  merged   148263          66
# 4         5.0        3  merged   252712          65
#
#                                                 api_url  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit
# 1  https://api.github.com/repos/kennethkalmer/ruote-kit
# 2       https://api.github.com/repos/matplotlib/basemap
# 3       https://api.github.com/repos/matplotlib/basemap
# 4       https://api.github.com/repos/matplotlib/basemap
#
#                                           url  \
# 0  https://github.com/kennethkalmer/ruote-kit
# 1  https://github.com/kennethkalmer/ruote-kit
# 2       https://github.com/matplotlib/basemap
# 3       https://github.com/matplotlib/basemap
# 4       https://github.com/matplotlib/basemap
#
#                                                pr_url  \
# 0  https://github.com/kennethkalmer/ruote-kit/pull/16
# 1  https://github.com/kennethkalmer/ruote-kit/pull/14
# 2       https://github.com/matplotlib/basemap/pull/64
# 3       https://github.com/matplotlib/basemap/pull/66
# 4       https://github.com/matplotlib/basemap/pull/65
#
#                                                       pr_api_url author_id  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/16     iamer
# 1  https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/14     iamer
# 2       https://api.github.com/repos/matplotlib/basemap/pulls/64  pmarshwx
# 3       https://api.github.com/repos/matplotlib/basemap/pulls/66  pmarshwx
# 4       https://api.github.com/repos/matplotlib/basemap/pulls/65  pmarshwx
#
#                                                                                       author_desc_body  \
# 0         One more minor fix that helps with some crashes in case of process with no root expression\n
# 1                                                 Don't crash when a process has no root expression.\n
# 2  Here's my first attempt to extend the new latlon keyword argument to the more generic plot metho...
# 3  This fixes the scenario where plotting fails when a user passes latlon=False to a 2d plotting fu...
# 4  Here is the first go at adding functionality for drawing counties on a map. It reads in a UScoun...
#
#    closer_id  comments_counts  \
# 0  jmettraux              0.0
# 1  jmettraux              0.0
# 2     jswhit              7.0
# 3     jswhit              3.0
# 4     jswhit              9.0
#
#                                                                                               comments  \
# 0                                                                                                   []
# 1                                                                                                   []
# 2  ["You've handled the map projection transformation part, but what about the longitude shifting p...
# 3  ["I hadn't thought of that. It is a cleaner approach to the problem.\n\nBeing a relative newcome...
# 4  ["What's the source of the counties shapefile?  We should add a LICENSE file somewhere.\n\nAre t...
#
#    commit_counts  code_changes_counts            created_at  \
# 0            1.0                  1.0  2012-01-04T10:23:49Z
# 1            1.0                  1.0  2011-12-12T22:10:13Z
# 2            3.0                  1.0  2012-08-08T04:30:44Z
# 3            1.0                  1.0  2012-08-19T20:21:14Z
# 4            4.0                  6.0  2012-08-18T20:00:41Z
#
#               closed_at  checked author_country closer_country  \
# 0  2012-01-04T10:53:37Z      1.0             \N          japan
# 1  2011-12-12T22:13:44Z      1.0             \N          japan
# 2  2012-08-20T22:32:28Z      1.0  united states             \N
# 3  2012-08-20T22:32:29Z      1.0  united states             \N
# 4  2012-08-21T12:12:02Z      1.0  united states             \N
#
#   author_continent same_country author_eth closer_eth  same_eth  prs_white  \
# 0               \N            0    Unknown      White         0   0.763503
# 1               \N            0    Unknown      White         0   0.763503
# 2    North America            0      White      White         1   0.964081
# 3    North America            0      White      White         1   0.964081
# 4    North America            0      White      White         1   0.964081
#
#     prs_api  prs_black  prs_hispanic  pri_white  pri_black   pri_api  \
# 0  0.187838   0.007003      0.001286   0.974386   0.011098  0.005310
# 1  0.187838   0.007003      0.001286   0.974386   0.011098  0.005310
# 2  0.001878   0.030626      0.001998   0.937730   0.058950  0.000949
# 3  0.001878   0.030626      0.001998   0.937730   0.058950  0.000949
# 4  0.001878   0.030626      0.001998   0.937730   0.058950  0.000949
#
#    pri_hispanic prs_eth_8 prs_eth_7 prs_eth_9 prs_eth_diff prs_eth_diff_2
# 0      0.008516   Unknown     White   Unknown      Unknown        Unknown
# 1      0.008516   Unknown     White   Unknown      Unknown        Unknown
# 2      0.001142     White     White     White        White          White
# 3      0.001142     White     White     White        White          White
# 4      0.001142     White     White     White        White          White

# %%
# fill the NaN values in column author_desc_body with \N
df_merged['author_desc_body'] = df_merged['author_desc_body'].fillna('\\N')

# %%
df_merged.head()
# Out:
#    Unnamed: 0  repo_id  status    pr_id  pullreq_id  \
# 0         1.0        2  merged   852598          16
# 1         2.0        2  merged  1052366          14
# 2         3.0        3  merged    12308          64
# 3         4.0        3  merged   148263          66
# 4         5.0        3  merged   252712          65
#
#                                                 api_url  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit
# 1  https://api.github.com/repos/kennethkalmer/ruote-kit
# 2       https://api.github.com/repos/matplotlib/basemap
# 3       https://api.github.com/repos/matplotlib/basemap
# 4       https://api.github.com/repos/matplotlib/basemap
#
#                                           url  \
# 0  https://github.com/kennethkalmer/ruote-kit
# 1  https://github.com/kennethkalmer/ruote-kit
# 2       https://github.com/matplotlib/basemap
# 3       https://github.com/matplotlib/basemap
# 4       https://github.com/matplotlib/basemap
#
#                                                pr_url  \
# 0  https://github.com/kennethkalmer/ruote-kit/pull/16
# 1  https://github.com/kennethkalmer/ruote-kit/pull/14
# 2       https://github.com/matplotlib/basemap/pull/64
# 3       https://github.com/matplotlib/basemap/pull/66
# 4       https://github.com/matplotlib/basemap/pull/65
#
#                                                       pr_api_url author_id  \
# 0  https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/16     iamer
# 1  https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/14     iamer
# 2       https://api.github.com/repos/matplotlib/basemap/pulls/64  pmarshwx
# 3       https://api.github.com/repos/matplotlib/basemap/pulls/66  pmarshwx
# 4       https://api.github.com/repos/matplotlib/basemap/pulls/65  pmarshwx
#
#                                                                                       author_desc_body  \
# 0         One more minor fix that helps with some crashes in case of process with no root expression\n
# 1                                                 Don't crash when a process has no root expression.\n
# 2  Here's my first attempt to extend the new latlon keyword argument to the more generic plot metho...
# 3  This fixes the scenario where plotting fails when a user passes latlon=False to a 2d plotting fu...
# 4  Here is the first go at adding functionality for drawing counties on a map. It reads in a UScoun...
#
#    closer_id  comments_counts  \
# 0  jmettraux              0.0
# 1  jmettraux              0.0
# 2     jswhit              7.0
# 3     jswhit              3.0
# 4     jswhit              9.0
#
#                                                                                               comments  \
# 0                                                                                                   []
# 1                                                                                                   []
# 2  ["You've handled the map projection transformation part, but what about the longitude shifting p...
# 3  ["I hadn't thought of that. It is a cleaner approach to the problem.\n\nBeing a relative newcome...
# 4  ["What's the source of the counties shapefile?  We should add a LICENSE file somewhere.\n\nAre t...
#
#    commit_counts  code_changes_counts            created_at  \
# 0            1.0                  1.0  2012-01-04T10:23:49Z
# 1            1.0                  1.0  2011-12-12T22:10:13Z
# 2            3.0                  1.0  2012-08-08T04:30:44Z
# 3            1.0                  1.0  2012-08-19T20:21:14Z
# 4            4.0                  6.0  2012-08-18T20:00:41Z
#
#               closed_at  checked    prs_country prc_country  prs_continent  \
# 0  2012-01-04T10:53:37Z      1.0             \N       japan             \N
# 1  2011-12-12T22:13:44Z      1.0             \N       japan             \N
# 2  2012-08-20T22:32:28Z      1.0  united states          \N  North America
# 3  2012-08-20T22:32:29Z      1.0  united states          \N  North America
# 4  2012-08-21T12:12:02Z      1.0  united states          \N  North America
#
#   prs_pri_same_nationality  prs_eth prc_eth  same_eth  prs_white   prs_api  \
# 0                        0  Unknown   White         0   0.763503  0.187838
# 1                        0  Unknown   White         0   0.763503  0.187838
# 2                        0    White   White         1   0.964081  0.001878
# 3                        0    White   White         1   0.964081  0.001878
# 4                        0    White   White         1   0.964081  0.001878
#
#    prs_black  prs_hispanic  pri_white  pri_black   pri_api  pri_hispanic  \
# 0   0.007003      0.001286   0.974386   0.011098  0.005310      0.008516
# 1   0.007003      0.001286   0.974386   0.011098  0.005310      0.008516
# 2   0.030626      0.001998   0.937730   0.058950  0.000949      0.001142
# 3   0.030626      0.001998   0.937730   0.058950  0.000949      0.001142
# 4   0.030626      0.001998   0.937730   0.058950  0.000949      0.001142
#
#   prs_eth_8 prs_eth_7 prs_eth_9 prs_eth_diff prs_eth_diff_2
# 0   Unknown     White   Unknown      Unknown        Unknown
# 1   Unknown     White   Unknown      Unknown        Unknown
# 2     White     White     White        White          White
# 3     White     White     White        White          White
# 4     White     White     White        White          White

# %%
df_merged.to_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/pr_merged_final_April_2023.csv", index=False)

# %%
df_test = pd.read_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/pr_merged_final_April_2023.csv")

# %%
df_test.count()
# Out:
# Unnamed: 0             1980653
# repo_id                1980653
# status                 1980653
# pr_id                  1980653
# pullreq_id             1980653
# api_url                1980653
#  url                   1980653
# pr_url                 1980653
# pr_api_url             1980653
# author_id              1980653
# author_desc_body       1980653
# closer_id              1973123
# comments_counts        1980653
# comments               1973106
# commit_counts          1980653
# code_changes_counts    1980653
# created_at             1980653
# closed_at              1980622
# checked                1980653
# author_country         1980653
# closer_country         1980653
# author_continent       1980653
# same_country           1980653
# author_eth             1980653
# closer_eth             1980653
# same_eth               1980653
# prs_white              1922111
# prs_api                1922111
# prs_black              1922111
# prs_hispanic           1922111
# pri_white              1949162
# pri_black              1949162
# pri_api                1949162
# pri_hispanic           1949162
# prs_eth_8              1980653
# prs_eth_7              1980653
# prs_eth_9              1980653
# prs_eth_diff           1980653
# prs_eth_diff_2         1980653
# dtype: int64

# %%
#df_merged = df_merged.fillna(r"\N")

# %%
df_merged.dtypes
# Out:
# Unnamed: 0               int64
# repo_id                  int64
# status                  object
# pr_id                    int64
# pullreq_id               int64
# api_url                 object
#  url                    object
# pr_url                  object
# pr_api_url              object
# author_id               object
# author_desc_body        object
# closer_id              float64
# comments_counts          int64
# comments                object
# commit_counts            int64
# code_changes_counts      int64
# created_at              object
# closed_at               object
# checked                  int64
# author_country          object
# closer_country          object
# author_continent        object
# same_country             int64
# author_eth              object
# closer_eth              object
# same_eth                 int64
# dtype: object

# %%
df_complete = df_complete.astype({'Unnamed: 0': 'int64', 'comments_counts': 'int64', 'commit_counts': 'int64', 'code_changes_counts': 'int64'})

# %%
#merging the non-merged and merged together 
df_complete = pd.concat([df_as, df_as_merged], ignore_index=True)

# %%
# and order dataframe by unnamed:0 column
df_complete = df_complete.sort_values(by=['Unnamed: 0'])

# %%
df_complete
# Out:
#          Unnamed: 0    repo_id      status     pr_id  pullreq_id  \
# 0                 0          2  not-merged     33026          18
# 1                 1          2      merged    852598          16
# 2                 2          2      merged   1052366          14
# 3                 3          3      merged     12308          64
# 4                 4          3      merged    148263          66
# ...             ...        ...         ...       ...         ...
# 2414039     2507586   95968435      merged  48086112          36
# 2414040     2507587   95968435  not-merged  48086131          37
# 2414041     2507588   95968435      merged  53396348          38
# 2414042     2507589  100829843      merged  40786603           7
# 2414043     2507590  100829843      merged  41319413           8
#
#                                                       api_url  \
# 0        https://api.github.com/repos/kennethkalmer/ruote-kit
# 1        https://api.github.com/repos/kennethkalmer/ruote-kit
# 2        https://api.github.com/repos/kennethkalmer/ruote-kit
# 3             https://api.github.com/repos/matplotlib/basemap
# 4             https://api.github.com/repos/matplotlib/basemap
# ...                                                       ...
# 2414039       https://api.github.com/repos/sio2project/oioioi
# 2414040       https://api.github.com/repos/sio2project/oioioi
# 2414041       https://api.github.com/repos/sio2project/oioioi
# 2414042   https://api.github.com/repos/ulule/django-courriers
# 2414043   https://api.github.com/repos/ulule/django-courriers
#
#                                                 url  \
# 0        https://github.com/kennethkalmer/ruote-kit
# 1        https://github.com/kennethkalmer/ruote-kit
# 2        https://github.com/kennethkalmer/ruote-kit
# 3             https://github.com/matplotlib/basemap
# 4             https://github.com/matplotlib/basemap
# ...                                             ...
# 2414039       https://github.com/sio2project/oioioi
# 2414040       https://github.com/sio2project/oioioi
# 2414041       https://github.com/sio2project/oioioi
# 2414042   https://github.com/ulule/django-courriers
# 2414043   https://github.com/ulule/django-courriers
#
#                                                      pr_url  \
# 0        https://github.com/kennethkalmer/ruote-kit/pull/18
# 1        https://github.com/kennethkalmer/ruote-kit/pull/16
# 2        https://github.com/kennethkalmer/ruote-kit/pull/14
# 3             https://github.com/matplotlib/basemap/pull/64
# 4             https://github.com/matplotlib/basemap/pull/66
# ...                                                     ...
# 2414039       https://github.com/sio2project/oioioi/pull/36
# 2414040       https://github.com/sio2project/oioioi/pull/37
# 2414041       https://github.com/sio2project/oioioi/pull/38
# 2414042    https://github.com/ulule/django-courriers/pull/7
# 2414043    https://github.com/ulule/django-courriers/pull/8
#
#                                                             pr_api_url  \
# 0        https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/18
# 1        https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/16
# 2        https://api.github.com/repos/kennethkalmer/ruote-kit/pulls/14
# 3             https://api.github.com/repos/matplotlib/basemap/pulls/64
# 4             https://api.github.com/repos/matplotlib/basemap/pulls/66
# ...                                                                ...
# 2414039       https://api.github.com/repos/sio2project/oioioi/pulls/36
# 2414040       https://api.github.com/repos/sio2project/oioioi/pulls/37
# 2414041       https://api.github.com/repos/sio2project/oioioi/pulls/38
# 2414042    https://api.github.com/repos/ulule/django-courriers/pulls/7
# 2414043    https://api.github.com/repos/ulule/django-courriers/pulls/8
#
#                author_id  \
# 0                reedlaw
# 1                  iamer
# 2                  iamer
# 3               pmarshwx
# 4               pmarshwx
# ...                  ...
# 2414039     koluckirafal
# 2414040          MCMrARM
# 2414041     wiktorkuchta
# 2414042  louiseGrandjonc
# 2414043  louiseGrandjonc
#
#                                                                                             author_desc_body  \
# 0                                                                                                        NaN
# 1               One more minor fix that helps with some crashes in case of process with no root expression\n
# 2                                                       Don't crash when a process has no root expression.\n
# 3        Here's my first attempt to extend the new latlon keyword argument to the more generic plot metho...
# 4        This fixes the scenario where plotting fails when a user passes latlon=False to a 2d plotting fu...
# ...                                                                                                      ...
# 2414039                                                                                                  NaN
# 2414040                                                                                                  NaN
# 2414041  Probably would also be nice to have it prefixed with the selected tab's title but idk how to do ...
# 2414042                                                                                                  NaN
# 2414043                                                                                                  NaN
#
#          closer_id  comments_counts  \
# 0              NaN                1
# 1        jmettraux                0
# 2        jmettraux                0
# 3           jswhit                7
# 4           jswhit                3
# ...            ...              ...
# 2414039      accek                0
# 2414040        NaN                1
# 2414041      accek                0
# 2414042      thoas                0
# 2414043      thoas                0
#
#                                                                                                     comments  \
# 0        ["Hello, thanks for the pull request. I fixed it in another way for https://github.com/kennethka...
# 1                                                                                                         []
# 2                                                                                                         []
# 3        ["You've handled the map projection transformation part, but what about the longitude shifting p...
# 4        ["I hadn't thought of that. It is a cleaner approach to the problem.\n\nBeing a relative newcome...
# ...                                                                                                      ...
# 2414039                                                                                                   []
# 2414040                                                                                ['Duplicate of #36 ']
# 2414041                                                                                                   []
# 2414042                                                                                                   []
# 2414043                                                                                                   []
#
#          commit_counts  code_changes_counts            created_at  \
# 0                    1                    1  2012-02-16T22:18:05Z
# 1                    1                    1  2012-01-04T10:23:49Z
# 2                    1                    1  2011-12-12T22:10:13Z
# 3                    3                    1  2012-08-08T04:30:44Z
# 4                    1                    1  2012-08-19T20:21:14Z
# ...                ...                  ...                   ...
# 2414039              1                    5  2018-10-21T17:02:36Z
# 2414040              1                    5  2018-10-21T17:03:02Z
# 2414041              2                    2  2019-01-13T21:44:07Z
# 2414042             21                   25  2018-05-17T16:27:20Z
# 2414043              4                    1  2018-06-22T14:03:20Z
#
#                     closed_at author_country closer_country author_continent  \
# 0        2012-02-18T02:13:05Z  united states          japan    North America
# 1        2012-01-04T10:53:37Z             \N          japan               \N
# 2        2011-12-12T22:13:44Z             \N          japan               \N
# 3        2012-08-20T22:32:28Z  united states             \N    North America
# 4        2012-08-20T22:32:29Z  united states             \N    North America
# ...                       ...            ...            ...              ...
# 2414039  2018-10-23T11:12:50Z         poland         poland           Europe
# 2414040  2018-10-22T22:27:09Z             \N         poland               \N
# 2414041  2019-01-28T20:12:55Z             \N         poland               \N
# 2414042  2018-06-12T09:54:17Z             \N         france               \N
# 2414043  2018-06-28T12:55:45Z             \N         france               \N
#
#         same_country author_eth closer_eth  same_eth  prs_white   prs_api  \
# 0                  0      White      White         1   0.923822  0.030206
# 1                  0    Unknown      White         0   0.763503  0.187838
# 2                  0    Unknown      White         0   0.763503  0.187838
# 3                  0      White      White         1   0.964081  0.001878
# 4                  0      White      White         1   0.964081  0.001878
# ...              ...        ...        ...       ...        ...       ...
# 2414039            1      White      White         1   0.999191  0.000308
# 2414040            0    Unknown      White         0   0.303911  0.686865
# 2414041            0    Unknown      White         0        NaN       NaN
# 2414042            0    Unknown      White         0   0.303911  0.686865
# 2414043            0    Unknown      White         0   0.303911  0.686865
#
#          prs_black  prs_hispanic  pri_white  pri_black   pri_api  \
# 0         0.043507      0.001134   0.974386   0.011098  0.005310
# 1         0.007003      0.001286   0.974386   0.011098  0.005310
# 2         0.007003      0.001286   0.974386   0.011098  0.005310
# 3         0.030626      0.001998   0.937730   0.058950  0.000949
# 4         0.030626      0.001998   0.937730   0.058950  0.000949
# ...            ...           ...        ...        ...       ...
# 2414039   0.000075      0.000421   0.981248   0.002554  0.005854
# 2414040   0.002034      0.004707   0.981248   0.002554  0.005854
# 2414041        NaN           NaN   0.981248   0.002554  0.005854
# 2414042   0.002034      0.004707   0.999281   0.000120  0.000253
# 2414043   0.002034      0.004707   0.999281   0.000120  0.000253
#
#          pri_hispanic prs_eth_8 prs_eth_7 prs_eth_9 prs_eth_diff  \
# 0            0.008516     White     White     White        White
# 1            0.008516   Unknown     White   Unknown      Unknown
# 2            0.008516   Unknown     White   Unknown      Unknown
# 3            0.001142     White     White     White        White
# 4            0.001142     White     White     White        White
# ...               ...       ...       ...       ...          ...
# 2414039      0.009472     White     White     White        White
# 2414040      0.009472   Unknown   Unknown   Unknown          API
# 2414041      0.009472   Unknown   Unknown   Unknown      Unknown
# 2414042      0.000347   Unknown   Unknown   Unknown          API
# 2414043      0.000347   Unknown   Unknown   Unknown          API
#
#         prs_eth_diff_2
# 0                White
# 1              Unknown
# 2              Unknown
# 3                White
# 4                White
# ...                ...
# 2414039          White
# 2414040            API
# 2414041        Unknown
# 2414042            API
# 2414043            API
#
# [2414044 rows x 38 columns]

# %%
df_complete = pd.merge(df_complete, df_ieee[['pr_id', 'prs_country', 'prc_country','prs_continent', 'prs_pri_same_nationality', 'prs_eth', 'prc_eth', 'same_eth', 'prs_white', 'prs_api', 'prs_black', 'prs_hispanic', 'pri_white', 'pri_black', 'pri_api', 'pri_hispanic', 'prs_eth_8', 'prs_eth_7', 'prs_eth_9', 'prs_eth_diff', 'prs_eth_diff_2']], on='pr_id', how='left', validate='one_to_one')

# %%
df_complete.to_csv("/Users/amirrshams/UW/Thesis/Datasets/pr_final_April_2023.csv", index=False)
