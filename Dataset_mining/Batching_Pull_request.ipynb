# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/pr_merged.csv")
# Out:
# /var/folders/v7/m50ww3p142130jtt2scggl3r0000gq/T/ipykernel_92930/1718427395.py:1: DtypeWarning: Columns (9,10,11,12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/pr_merged.csv")

# %%
df.count()
# Out:
# Unnamed: 0             2039601
# repo_id                2039601
# status                 2039601
# pr_id                  2039601
# pullreq_id             2039601
# api_url                2039601
#  url                   2039601
# pr_url                 2039601
# pr_api_url             2033630
# author_id               161357
# author_desc_body        133782
# closer_id               161331
# comments_counts         161357
# comments                161301
# commit_counts           161357
# code_changes_counts     161357
# created_at              161357
# closed_at               161357
# checked                 161411
# dtype: int64

# %%
batch_size = 50000
df_batches = [df[i:i+batch_size] for i in range(0, len(df), batch_size)]

# %%
df_batches[0]
# Out:
#        Unnamed: 0  repo_id  status     pr_id  pullreq_id  \
# 0               1        2  merged    852598          16
# 1               2        2  merged   1052366          14
# 2               3        3  merged     12308          64
# 3               4        3  merged    148263          66
# 4               5        3  merged    252712          65
# ...           ...      ...     ...       ...         ...
# 49995       64661      750  merged  29199714       15986
# 49996       64662      750  merged  29212210       15988
# 49997       64663      750  merged  29213334       15989
# 49998       64664      750  merged  29220763       15990
# 49999       64665      750  merged  29220929       15991
#
#                                                  api_url  \
# 0      https://api.github.com/repos/kennethkalmer/ruo...
# 1      https://api.github.com/repos/kennethkalmer/ruo...
# 2        https://api.github.com/repos/matplotlib/basemap
# ...

# %%
df_batches[0].to_csv("/Users/amirrshams/UW/Thesis/Datasets/merged/Output/pr_output_batch_1.csv", index=False)
